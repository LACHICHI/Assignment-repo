# %% [markdown]
# <font color="blue"><h1>ASSIGNMENT</h1></font>

# %% [markdown]
# # Question 1
#
# Write a Python code to numerically solve the time-independent Schrödinger equation for a particle in a one-dimensional potential well. The potential energy function is given by:
#
#
# V(x) = { 0         , for 0 $\leq$ x $\leq$ a <br />
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;       V$_0$       , for a $\lt$ x $\leq$ b <br />
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;       infinity  , for x $\lt$ 0 or x $\gt$ b <br />
#       } <br />
#
# where a and b are the width of the well and the total width of the system, respectively, and V$_0$ is the height of the potential barrier. <br />
#
# Use the finite difference method to discretize the wavefunction and the potential energy function, and solve the resulting eigenvalue problem using the numpy library. Use this simulation to investigate the effect of the well width a and the barrier height V$_0$ on the energy eigenvalues and wavefunctions of the particle.<br />
#
# Additionally, use the matplotlib library to plot the energy eigenvalues and wavefunctions as a function of a and V$_0$, and discuss the physical significance of the results.
#
#
# ***Make Use of Classes for your solution***

# %% [markdown]
# # Instruction:
#
# For this assignment, submission must be done via Github.
# Create a Guthub account and an Assignment repo. A google sheet will be circulated. On the Google sheet, enter your Github URL. Ensure that the URL is correctly inserted. <br />
#
#
# Your submission should follow the structure below. You are at liberty to include images or text as you deem fit. However, they must be sound and relate to the topic. <br />
#
# <h3> Deadline: 3rd May 2023 (12:00 Midday) </h3>

# %% [markdown]
# <font color="red"><h2> Background</h2></font>
#
# - Briefly describe what Computational Physics is (A Brief Bakground)<br />
# - Link it to the task you have been given <br />
# - Outline your objectives for this study

# %% [markdown]
# The use of computational techniques and algorithms to resolve intricate physical issues that cannot be resolved analytically is known as computational physics. It makes use of computer programs, mathematical models, and algorithms for numerical simulations, data analysis, and modeling. In order for physicists to analyze complicated systems, the behavior of subatomic particles, or the structure of galaxies, computational physics has grown in importance in many areas of physics, including condensed matter physics, astrophysics, particle physics, biophysics, and fluid dynamics. The time-independent Schrodinger equation, which defines the behavior of quantum systems, is one of the key issues in physics. The position and time factors affect how the particle's wave function behaves in this equation.
# Python is a popular programming language that is utilized in computational physics because of how simple and adaptable it is to use. It offers a range of libraries and modules, such as Numpy, Scipy, and Matplotlib, that can be used for scientific computing.
# The finite difference approach is used to solve the differential equation and discretize the spatial coordinates in order to numerically solve the time-independent Schrodinger equation for a particle in a one-dimensional potential well. Python code can be used to create software that determines the wave function and particle energy levels.
#
# OBJECTIVES FOR THIS STUDY
# 1. to use numerical techniques to achieve a precise solution for the wave    function and energy eigenvalues of a particle in a one-dimensional potential well.
# 2. to investigate how the wave function behaves in various areas of the potential well and to examine how this behavior relates to the particle's energy.
# 3. to investigate the impact of altering the potential characteristics, such as the well's depth and width, on how the wave function and energy eigenvalues behave.
# 4.	to become proficient in Python programming for scientific computation, including data analysis, data visualization, and numerical methods for solving differential equations.
# 5.	to get ready for a job in one of the computational physics-intensive fields such as research, engineering, or data analysis.
# 6.	to comprehend quantum systems' behavior and elements including probability, wave functions, and energy levels. This can shed light on how real-world systems like atoms, molecules, and materials behave.
# 7.	to provide computational techniques and algorithms that can address challenging physics issues that cannot be resolved analytically. New technologies and applications in fields like quantum computing, materials science, and biology may result from this.

# %% [markdown]
# <font color="red"><h2> Method and Results </h2></font>
#
# - Solve the question here and discuss the results <br />

# %%
import numpy as np
import matplotlib.pyplot as plt

class Potential:
    def __init__(self, a, b, V):

        self.a = a
        self.b = b
        self.V = V

    def V_func(self, x):
        if 0 <= x <= self.a:
            return 0
        elif self.a < x <= self.b:
            return self.V
        else:
            return np.inf

class Schrodinger:

    def __init__(self, potential_well, N=1000):
        self.potential_well = potential_well
        self.N = N
        self.dx = potential_well.b / N
        self.x = np.linspace(0, potential_well.b, N)
        self.V_arr = np.array([potential_well.V_func(xi) for xi in self.x])

    def solve(self):


        H = np.zeros((self.N, self.N))
        for i in range(self.N):
            H[i, i] = 2.0 / self.dx**2 + self.V_arr[i]
            if i > 0:
                H[i, i-1] = -1.0 / self.dx**2
            if i < self.N-1:
                H[i, i+1] = -1.0 / self.dx**2
        E, psi = np.linalg.eigh(H)
        self.E = E
        self.psi = psi

    def PlotEigenvalues(self):
        plt.plot(range(1, self.N+1), self.E, 'o')
        plt.xlabel('Eigenvalue index')
        plt.title('Energy Eigenvalues')
        plt.ylabel('Energy')
        plt.show()

    def PlotWavefunctions(self, num=5):
        for i in range(num):
            plt.plot(self.x, self.psi[:, i], label=f'Eigenfunction {i+1}')
        plt.xlabel('Position ')
        plt.ylabel('Wavefunction')
        plt.legend()
        plt.show()



well1 = Potential(1.0, 2.0, 10.0)
solver1 = Schrodinger(well1)
solver1.solve()
solver1.PlotEigenvalues()
solver1.PlotWavefunctions()

# %% [markdown]
# <font color="red"><h2> Conclusion </h2></font>
#
# - Give a brief conclusion. <br />
# - Also, discuss your learning journey. Highlight your challenges and great moments. <br />

# %% [markdown]
# The solutions to the equation produce quantized energy levels that can be
# used to determine the probability of finding the particle at different
# locations in the well. The well can be infinite or finite depending on the
# boundary conditions that define the potential. The time-independent
# Schrodinger equation is an important tool for understanding the behavior of
# particles in potential wells.
#
# It can be difficult to learn how to use Python to numerically solve the
# time-independent Schrodinger equation for a particle in a one-dimensional
# potential well. However, one can be able to comprehend and use this concept
# with the correct tools, motivation, and direction. A fundamental understanding
# of the theoretical ideas of quantum mechanics, such as wave functions,
# energy eigenvalues, and potentials, is necessary to get started.Additionally
# you must be familiar with the programming language in this case, Python that will be used to complete the work. This will require familiarizing yourself with some of Python's fundamental grammar, including functions, if-else clauses, loops, and lists, among others.
#
# Understanding the intricate theoretical idea underlying the Schrodinger
# equation was one of the major obstacles on the path. This was made worse by
# the equation's variable-separated structure, which made it more challenging
# to understand. It was difficult to create a code to numerically solve the equation because it requires a thorough knowledge of the language.
#
# Despite these obstacles, there were other times when learning advanced significantly. The successful application of the algorithm to resolve the Schrodinger equation was one such instance. It was amazing to see how the programming language and theoretical ideas combined to produce a practical solution. This answer made it possible to graphically portray the wave function, which heightened the excitement around the discovery.

# %% [markdown]
# <font color="red"><h2> Recommendation(s) </h2></font>
#
# - What area(s) do you suggest the class covers? <br />

# %% [markdown]
# There are a few topics that the class ought to address in order to improve the learning process. These involve comprehending the Schrodinger equation's theoretical underpinnings and grasping the basic ideas of quantum physics. A thorough introduction to Python programming should also be included, covering all the essential syntax and functions for writing the equation in code. The course should also include exercises and real-world examples so that students can practice and improve their abilities to use Python to solve the Schrodinger equation.
